# %% [markdown]
# <a href="https://colab.research.google.com/github/mocacookiecrubmle/pandas/blob/main/Exploratory_data_analysis_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Some basic intro to Pandas
# Importing pandas into a notebook
import pandas as pd

# %% [markdown]
# lets import a dataset based on salaries of data scientics.

# %%
#importing a data set to work on in this analysis
url = '/content/drive/MyDrive/ds_salaries.csv'
salary= pd.read_csv(url)

# %%
#confirm if file is loaded 
salary
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#top 25 rows of data set
salary.head(25)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# 5            5       2020               EN              FT
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
# 11          11       2020               MI              FT
# 12          12       2020               EN              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
# ...

# %%
#data types in each column are as per below
salary.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
salary.job_title.head()
# Out:
# 0                Data Scientist
# 1    Machine Learning Scientist
# 2             Big Data Engineer
# 3          Product Data Analyst
# 4     Machine Learning Engineer
# Name: job_title, dtype: object

# %%
type(salary['job_title'])
# Out:
# pandas.core.series.Series

# %%
#salary above 20000
above20K = salary["salary"]>20000
above20K.tail()
# Out:
# 602    True
# 603    True
# 604    True
# 605    True
# 606    True
# Name: salary, dtype: bool

# %%
#know the size of your dataset
salary.shape
# Out:
# (607, 12)

# %%
#select some specific rows
salary.iloc[6:25]
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
# 11          11       2020               MI              FT
# 12          12       2020               EN              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
# 15          15       2020               MI              FT
# 16          16       2020               EN              FT
# 17          17       2020               SE              FT
# 18          18       2020               EN              FT
# 19          19       2020               MI              FT
# 20          20       2020               MI              FT
# ...

# %%
#make some changes to rows
salary.iloc[0:3, 3] = " unknown "
salary.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI        unknown
# 1           1       2020               SE        unknown
# 2           2       2020               SE        unknown
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
salary
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI        unknown
# 1             1       2020               SE        unknown
# 2             2       2020               SE        unknown
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
url = '/content/drive/MyDrive/ds_salaries.csv'
salary= pd.read_csv(url)
salary
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# using matplotlib for visualizations
import matplotlib.pyplot as plt
salary.plot()

# %%
#plotting how salaries look
salary["salary_in_usd"].plot()

# %%
#plotting how salries relate to experience level
salary.plot.scatter(x="experience_level", y="salary_in_usd", alpha=0.5)

# %%
#plotting how salaires varies by company location
salary.plot.scatter(y="company_location", x="salary_in_usd", alpha=0.95, figsize=(14,14))

# %%
#create new columns derived from existing columns
salary["salary in CAD"] = salary["salary_in_usd"] / 0.60
salary.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size  \
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#rename a column
salary_rename = salary.rename(
    
    columns={ "work_year": "year"}
)

# %%
salary_rename.head()
# Out:
#    Unnamed: 0  year experience_level employment_type  \
# 0           0  2020               MI              FT
# 1           1  2020               SE              FT
# 2           2  2020               SE              FT
# 3           3  2020               MI              FT
# 4           4  2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size  \
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
salary= salary_rename
salary
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 0             0  2020               MI              FT
# 1             1  2020               SE              FT
# 2             2  2020               SE              FT
# 3             3  2020               MI              FT
# 4             4  2020               SE              FT
# ..          ...   ...              ...             ...
# 602         602  2022               SE              FT
# 603         603  2022               SE              FT
# 604         604  2022               SE              FT
# 605         605  2022               SE              FT
# 606         606  2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
#checking mean salary
salary["salary in CAD"].mean()
# Out:
# 187163.11641954974

# %%
#checking median
salary[["year", "salary_in_usd"]].median()
# Out:
# year               2022.0
# salary_in_usd    101570.0
# dtype: float64

# %%
#describing data
salary[["year", "salary_in_usd"]].describe()
# Out:
#               year  salary_in_usd
# count   607.000000     607.000000
# mean   2021.405272  112297.869852
# std       0.692133   70957.259411
# min    2020.000000    2859.000000
# 25%    2021.000000   62726.000000
# 50%    2022.000000  101570.000000
# 75%    2022.000000  150000.000000
# max    2022.000000  600000.000000

# %%
#grouping data
salary[["year", "salary_in_usd"]].groupby("year").mean()
# Out:
#       salary_in_usd
# year
# 2020   95813.000000
# 2021   99853.792627
# 2022  124522.006289

# %%
#drop a column
salary.drop("salary", axis=1)
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 0             0  2020               MI              FT
# 1             1  2020               SE              FT
# 2             2  2020               SE              FT
# 3             3  2020               MI              FT
# 4             4  2020               SE              FT
# ..          ...   ...              ...             ...
# 602         602  2022               SE              FT
# 603         603  2022               SE              FT
# 604         604  2022               SE              FT
# 605         605  2022               SE              FT
# 606         606  2022               MI              FT
#
#                       job_title salary_currency  salary_in_usd  \
# 0                Data Scientist             EUR          79833
# 1    Machine Learning Scientist             USD         260000
# 2             Big Data Engineer             GBP         109024
# ...

# %%
#sort by values
salary.sort_values(["experience_level"])
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 113         113  2021               EN              PT
# 139         139  2021               EN              FT
# 134         134  2021               EN              FT
# 131         131  2021               EN              FT
# 130         130  2021               EN              FT
# ..          ...   ...              ...             ...
# 364         364  2022               SE              FT
# 363         363  2022               SE              FT
# 362         362  2022               SE              FT
# 371         371  2022               SE              FT
# 303         303  2022               SE              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 113                AI Scientist   12000             USD          12000
# 139              Data Scientist   80000             USD          80000
# 134              Data Scientist  100000             USD         100000
# ...

# %%
#length of string
salary["job_title"].str.len()
# Out:
# 0      14
# 1      26
# 2      17
# 3      20
# 4      25
#        ..
# 602    13
# 603    13
# 604    12
# 605    12
# 606    12
# Name: job_title, Length: 607, dtype: int64

# %%
#Finding position of substring, if not found returns -1
salary["job_title"].str.find("D")
# Out:
# 0      0
# 1     -1
# 2      4
# 3      8
# 4     -1
#       ..
# 602    0
# 603    0
# 604    0
# 605    0
# 606   -1
# Name: job_title, Length: 607, dtype: int64

# %%
#find if a column has a string
salary["job_title"] == "Data Scientist"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# Name: job_title, Length: 607, dtype: bool

# %%
#find and replace a string
salary.replace("Data Scientist", "DSc")
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 0             0  2020               MI              FT
# 1             1  2020               SE              FT
# 2             2  2020               SE              FT
# 3             3  2020               MI              FT
# 4             4  2020               SE              FT
# ..          ...   ...              ...             ...
# 602         602  2022               SE              FT
# 603         603  2022               SE              FT
# 604         604  2022               SE              FT
# 605         605  2022               SE              FT
# 606         606  2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                           DSc   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
#Using a single column’s values to select data
salary[salary["salary_in_usd"]> 100000]
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 1             1  2020               SE              FT
# 2             2  2020               SE              FT
# 4             4  2020               SE              FT
# 6             6  2020               SE              FT
# 8             8  2020               MI              FT
# ..          ...   ...              ...             ...
# 602         602  2022               SE              FT
# 603         603  2022               SE              FT
# 604         604  2022               SE              FT
# 605         605  2022               SE              FT
# 606         606  2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 4     Machine Learning Engineer  150000             USD         150000
# ...

# %%
#seleting a specific row
salary.iloc[3]
# Out:
# Unnamed: 0                               3
# year                                  2020
# experience_level                        MI
# employment_type                         FT
# job_title             Product Data Analyst
# salary                               20000
# salary_currency                        USD
# salary_in_usd                        20000
# employee_residence                      HN
# remote_ratio                             0
# company_location                        HN
# company_size                             S
# salary in CAD                 33333.333333
# Name: 3, dtype: object

# %%
#seleting a specific set of rows
salary.iloc[3:35]
# Out:
#     Unnamed: 0  year experience_level employment_type  \
# 3            3  2020               MI              FT
# 4            4  2020               SE              FT
# 5            5  2020               EN              FT
# 6            6  2020               SE              FT
# 7            7  2020               MI              FT
# 8            8  2020               MI              FT
# 9            9  2020               SE              FT
# 10          10  2020               EN              FT
# 11          11  2020               MI              FT
# 12          12  2020               EN              FT
# 13          13  2020               MI              FT
# 14          14  2020               MI              FT
# 15          15  2020               MI              FT
# 16          16  2020               EN              FT
# 17          17  2020               SE              FT
# 18          18  2020               EN              FT
# ...

# %%
salary.iloc[1:3, :]
# Out:
#    Unnamed: 0  year experience_level employment_type  \
# 1           1  2020               SE              FT
# 2           2  2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
#
#   employee_residence  remote_ratio company_location company_size  \
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
#
#    salary in CAD
# 1  433333.333333
# 2  181706.666667

# %%
#selecting speicif rows and columns
salary.iloc[[1, 2, 4], [0, 2]]
# Out:
#    Unnamed: 0 experience_level
# 1           1               SE
# 2           2               SE
# 4           4               SE

# %%
salary[salary["remote_ratio"] > 0]
# Out:
#      Unnamed: 0  year experience_level employment_type  \
# 2             2  2020               SE              FT
# 4             4  2020               SE              FT
# 5             5  2020               EN              FT
# 6             6  2020               SE              FT
# 7             7  2020               MI              FT
# ..          ...   ...              ...             ...
# 599         599  2022               MI              FT
# 602         602  2022               SE              FT
# 603         603  2022               SE              FT
# 605         605  2022               SE              FT
# 606         606  2022               MI              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 2            Big Data Engineer     85000             GBP         109024
# 4    Machine Learning Engineer    150000             USD         150000
# 5                 Data Analyst     72000             USD          72000
# ...

# %%
#check for empty cells
pd.isna(salary)
# Out:
#      Unnamed: 0   year  experience_level  employment_type  job_title  salary  \
# 0         False  False             False            False      False   False
# 1         False  False             False            False      False   False
# 2         False  False             False            False      False   False
# 3         False  False             False            False      False   False
# 4         False  False             False            False      False   False
# ..          ...    ...               ...              ...        ...     ...
# 602       False  False             False            False      False   False
# 603       False  False             False            False      False   False
# 604       False  False             False            False      False   False
# 605       False  False             False            False      False   False
# 606       False  False             False            False      False   False
#
# ...

# %%
salary.describe()
# Out:
#        Unnamed: 0         year        salary  salary_in_usd  remote_ratio  \
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000
#
#         salary in CAD
# count      607.000000
# mean    187163.116420
# std     118262.099019
# min       4765.000000
# 25%     104543.333333
# 50%     169283.333333
# 75%     250000.000000
# max    1000000.000000

# %%
import seaborn as sns
print(salary['salary_in_usd'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(salary['salary_in_usd'], color='r', bins=100, hist_kws={'alpha': 0.4})
# Out:
# count       607.000000
# mean     112297.869852
# std       70957.259411
# min        2859.000000
# 25%       62726.000000
# 50%      101570.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
list(set(salary.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64')]

# %%
df_num = salary.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Unnamed: 0  year  salary  salary_in_usd  remote_ratio  salary in CAD
# 0           0  2020   70000          79833             0  133055.000000
# 1           1  2020  260000         260000             0  433333.333333
# 2           2  2020   85000         109024            50  181706.666667
# 3           3  2020   20000          20000             0   33333.333333
# 4           4  2020  150000         150000            50  250000.000000

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f02cb522f50>,
# ...
#       dtype=object)

# %%
import numpy as np
salary.apply(np.max)
# Out:
# Unnamed: 0                             606
# year                                  2022
# experience_level                        SE
# employment_type                         PT
# job_title             Staff Data Scientist
# salary                            30400000
# salary_currency                        USD
# salary_in_usd                       600000
# employee_residence                      VN
# remote_ratio                           100
# company_location                        VN
# company_size                             S
# salary in CAD                    1000000.0
# dtype: object

# %%
sns.pairplot(salary)

# %%
sns.heatmap(salary.corr(), annot=True)
